# %% [markdown]
# # compensating saturated pulses
#
# ## Intro
#
# orthogonal decomposition for recovering linear behavior from saturated pulses

# %% [markdown]
# ## Loading Libraries

# %%
from pylab import *
import h5py
from scipy.optimize import curve_fit
#from scipy.stats import binned_statistic_dd
from scipy.stats import binned_statistic_dd
from scipy import optimize
import pickle
from scipy import stats
from scipy.stats.mstats import theilslopes
from scipy.signal import medfilt
from scipy.signal import savgol_filter
import os
import psana
import time

# %%
mpl.rcParams['axes.prop_cycle'] = cycler(color='bgcmyk')
mpl.rcParams['figure.figsize'] = (18,6)
plt.rcParams['image.cmap'] = 'rainbow'
#mpl.rcParams['text.usetex'] = True
#mpl.rcParams['font.family'] = 'Arial'
#mpl.rcParams['font.serif'] = 'Computer Modern Roman'
#mpl.rcParams['lines.linewidth'] = 1.5
mpl.rcParams['font.size'] = 18
mpl.rcParams['legend.fontsize'] = 10

# %% [markdown]
# ## Initializing Data

# %% [markdown]
# ### Loading Data

# %%
dsource = psana.MPIDataSource('exp=sxrlq8415:run=192:smd')
acq_det=psana.Detector("Acq01")
mcp_traces = []
apd_traces = []
photon_energy = []
stop_event = 5000000
smldata = dsource.small_data('sxrlq8415run192.h5',gather_interval=100)
my_dict = {}

# %%
for nevt,evt in enumerate(dsource.events()):
    if nevt>stop_event: break
    if (nevt%100==1): print nevt

    if(acq_det(evt) is None): continue

    mcp_wave = acq_det(evt)[0][2][1000:2000]-mean(acq_det(evt)[0][2][:300])
    apd_wave = acq_det(evt)[0][1][1000:2000]-mean(acq_det(evt)[0][1][:300])

    my_dict['mcp_data'] = sum(abs(fft(mcp_wave[400:]))[20:50])
    my_dict['apd_data'] = sum(apd_wave[190:230])
    
    smldata.event(my_dict)
    
smldata.save()
smldata.close()
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1001
# 1101
# 1201
# 1301
# 1401
# 1501
# 1601
# 1701
# 1801
# 1901
# 2001
# 2101
# 2201
# 2301
# 2401
# 2501
# 2601
# 2701
# 2801
# 2901
# 3001
# 3101
# 3201
# 3301
# 3401
# 3501
# 3601
# 3701
# 3801
# 3901
# 4001
# 4101
# 4201
# 4301
# 4401
# 4501
# 4601
# 4701
# 4801
# 4901
# 5001
# 5101
# 5201
# 5301
# 5401
# 5501
# 5601
# 5701
# 5801
# 5901
# 6001
# 6101
# 6201
# 6301
# 6401
# 6501
# 6601
# 6701
# 6801
# 6901
# 7001
# 7101
# 7201
# 7301
# 7401
# 7501
# 7601
# 7701
# 7801
# 7901
# 8001
# 8101
# 8201
# 8301
# 8401
# 8501
# 8601
# 8701
# 8801
# 8901
# 9001
# 9101
# 9201
# 9301
# 9401
# 9501
# 9601
# 9701
# 9801
# 9901
# 10001
# 10101
# 10201
# 10301
# 10401
# 10501
# 10601
# 10701
# 10801
# 10901
# 11001
# 11101
# 11201
# 11301
# 11401
# 11501
# 11601
# 11701
# 11801
# 11901
# 12001
# 12101
# 12201
# 12301
# 12401
# 12501
# 12601
# 12701
# 12801
# 12901
# 13001
# 13101
# 13201
# 13301
# 13401
# 13501
# 13601
# 13701
# 13801
# 13901
# 14001
# 14101
# 14201
# 14301
# 14401
# 14501
# 14601
# 14701
# 14801
# 14901
# 15001
# 15101
# 15201
# 15301
# 15401
# 15501
# 15601
# 15701
# 15801
# 15901
# 16001
# 16101
# 16201
# 16301
# 16401
# 16501
# 16601
# 16701
# 16801
# 16901
# 17001
# 17101
# 17201
# 17301
# 17401
# 17501
# 17601
# 17701
# 17801
# 17901
# 18001
# 18101
# 18201
# 18301
# 18401
# 18501
# 18601
# 18701
# 18801
# 18901
# 19001
# 19101
# 19201
# 19301
# 19401
# 19501
# 19601
# 19701
# 19801
# 19901
# 20001
# 20101
# 20201
# 20301
# 20401
# 20501
# 20601
# 20701
# 20801
# 20901
# 21001
# 21101
# 21201
# 21301
# 21401
# 21501
# 21601
# 21701
# 21801
# 21901
# 22001
# 22101
# 22201
# 22301
# 22401
# 22501
# 22601
# 22701
# 22801
# 22901
# 23001
# 23101
# 23201
# 23301
# 23401
# 23501
# 23601
# 23701
# 23801
# 23901
# 24001
# 24101
# 24201
# 24301
# 24401
# 24501
# 24601
# 24701
# 24801
# 24901
# 25001
# 25101
# 25201
# 25301
# 25401
# 25501
# 25601
# 25701
# 25801
# 25901
# 26001
# 26101
# 26201
# 26301
# 26401
# 26501
# 26601
# 26701
# 26801
# 26901
# 27001
# 27101
# 27201
# 27301
# 27401
# 27501
# 27601
# 27701
# 27801
# 27901
# 28001
# 28101
# 28201
# 28301
# 28401
# 28501
# 28601
# 28701
# 28801
# 28901
# 29001
# 29101
# 29201
# 29301
# 29401
# 29501
# 29601
# 29701
# 29801
# 29901
# 30001
# 30101
# 30201
# 30301
# 30401
# 30501
# 30601
# 30701
# 30801
# 30901
# 31001
# 31101
# 31201
# 31301
# 31401
# 31501
# 31601
# 31701
# 31801
# 31901
# 32001
# 32101
# 32201
# 32301
# 32401
# 32501
# 32601
# 32701
# 32801
# 32901
# 33001
# 33101
# 33201
# 33301
# 33401
# 33501
# 33601
# 33701
# 33801
# 33901
# 34001
# 34101
# 34201
# 34301
# 34401
# 34501
# 34601
# 34701
# 34801
# 34901
# 35001
# 35101
# 35201
# 35301
# 35401
# 35501
# 35601
# 35701
# 35801
# 35901
# 36001
# 36101
# 36201
# 36301
# 36401
# 36501
# 36601
# 36701
# 36801
# 36901
# 37001
# 37101
# 37201
# 37301
# 37401
# 37501
# 37601
# 37701
# 37801
# 37901
# 38001
# 38101
# 38201
# 38301
# 38401
# 38501
# 38601
# 38701
# 38801
# 38901
# 39001
# 39101
# 39201
# 39301
# 39401
# 39501
# 39601
# 39701
# 39801
# 39901
# 40001
# 40101
# 40201
# 40301
# 40401
# 40501
# 40601
# 40701
# 40801
# 40901
# 41001
# 41101
# 41201
# 41301
# 41401
# 41501
# 41601
# 41701
# 41801
# 41901
# 42001
# 42101
# 42201
# 42301
# 42401
# 42501
# 42601
# 42701
# 42801
# 42901
# 43001
# 43101
# 43201
# 43301
# 43401
# 43501
# 43601
# 43701
# 43801
# 43901
# 44001
# 44101
# 44201
# 44301
# 44401
# 44501
# 44601
# 44701
# 44801
# 44901
# 45001
# 45101
# 45201
# 45301
# 45401
# 45501
# 45601
# 45701
# 45801
# 45901
# 46001
# 46101
# 46201
# 46301
# 46401
# 46501
# 46601
# 46701
# 46801
# 46901
# 47001
# 47101
# 47201
# 47301
# 47401
# 47501
# 47601
# 47701
# 47801
# 47901
# 48001
# 48101
# 48201
# 48301
# 48401
# 48501
# 48601
# 48701
# 48801
# 48901
# 49001
# 49101
# 49201
# 49301
# 49401
# 49501
# 49601
# 49701
# 49801
# 49901
# 50001
# 50101

# %% [markdown]
# ## Visualizing Some Sample Data from the high speed digitizer (hsd)

# %%
my_data = h5py.File("sxrlq8415run192.h5")

# %%
photon_energy = nan_to_num(array(my_data['ebeam']['photon_energy']))
mcp_amplitude = nan_to_num(array(my_data['mcp_data']))
apd_amplitude = -nan_to_num(array(my_data['apd_data']))
fee_values = nan_to_num(array(my_data['gas_detector']['f_22_ENRC']))

# %%
hist(nan_to_num(fee_values),bins=arange(1.5,2,0.01))
# Out:
# (array([  3.80000000e+01,   4.70000000e+01,   5.70000000e+01,
#           6.40000000e+01,   9.00000000e+01,   1.16000000e+02,
#           1.44000000e+02,   2.09000000e+02,   2.38000000e+02,
#           3.01000000e+02,   3.22000000e+02,   4.56000000e+02,
#           5.80000000e+02,   6.66000000e+02,   8.42000000e+02,
#           9.78000000e+02,   1.21400000e+03,   1.38900000e+03,
#           1.74000000e+03,   1.90800000e+03,   2.23500000e+03,
#           2.38300000e+03,   2.40200000e+03,   2.65500000e+03,
#           2.82300000e+03,   2.88500000e+03,   2.80800000e+03,
#           2.71100000e+03,   2.73600000e+03,   2.45000000e+03,
#           2.23700000e+03,   1.95300000e+03,   1.70300000e+03,
#           1.36900000e+03,   1.16000000e+03,   9.63000000e+02,
#           7.28000000e+02,   5.29000000e+02,   4.14000000e+02,
#           2.78000000e+02,   1.85000000e+02,   1.09000000e+02,
#           7.90000000e+01,   4.80000000e+01,   2.70000000e+01,
#           2.10000000e+01,   1.20000000e+01,   6.00000000e+00,
#           2.00000000e+00]),
#  array([ 1.5 ,  1.51,  1.52,  1.53,  1.54,  1.55,  1.56,  1.57,  1.58,
#          1.59,  1.6 ,  1.61,  1.62,  1.63,  1.64,  1.65,  1.66,  1.67,
#          1.68,  1.69,  1.7 ,  1.71,  1.72,  1.73,  1.74,  1.75,  1.76,
#          1.77,  1.78,  1.79,  1.8 ,  1.81,  1.82,  1.83,  1.84,  1.85,
#          1.86,  1.87,  1.88,  1.89,  1.9 ,  1.91,  1.92,  1.93,  1.94,
#          1.95,  1.96,  1.97,  1.98,  1.99]),
#  <a list of 49 Patch objects>)

# %%
my_bins = arange(930,940,0.05)

IcovFEEvsE = histogram(photon_energy,my_bins, weights= (fee_values-mean(fee_values))*(apd_amplitude-mean(apd_amplitude)))[0]
IcovFEEvsE /= histogram(photon_energy, my_bins,weights= (fee_values-mean(fee_values))**2)[0]
plot(my_bins[1:],IcovFEEvsE)
ylim(-5,10)
show()


I0covFEEvsE = histogram(photon_energy,my_bins, weights= (fee_values-mean(fee_values))*(mcp_amplitude-mean(mcp_amplitude)))[0]
I0covFEEvsE /= histogram(photon_energy, my_bins,weights= (fee_values-mean(fee_values))**2)[0]
plot(my_bins[1:],I0covFEEvsE)
ylim(-2,5)
# Out:
# /reg/g/psdm/sw/conda/inst/miniconda2-prod-rhel7/envs/ana-1.3.55/lib/python2.7/site-packages/ipykernel/__main__.py:6: RuntimeWarning: invalid value encountered in divide
# /reg/g/psdm/sw/conda/inst/miniconda2-prod-rhel7/envs/ana-1.3.55/lib/python2.7/site-packages/ipykernel/__main__.py:13: RuntimeWarning: invalid value encountered in divide
# (-2, 5)

# %%
photon_energy = nan_to_num(array(my_data['ebeam']['photon_energy']))
mcp_amplitude = nan_to_num(array(my_data['mcp_data']))
apd_amplitude = -nan_to_num(array(my_data['apd_data']))
fee_values = nan_to_num(array(my_data['gas_detector']['f_22_ENRC']))

I_max = []
I0_max = []
step_size = 0.09
for i in arange(1.5,1.9,step_size):
    my_mask = array(my_data['gas_detector']['f_22_ENRC']) > i
    my_mask = my_mask*(array(my_data['gas_detector']['f_22_ENRC']) < i+step_size)
    
    photon_energy = array(my_data['ebeam']['photon_energy'])[my_mask]
    mcp_amplitude = array(my_data['mcp_data'])[my_mask]
    apd_amplitude = array(my_data['apd_data'])[my_mask]
    fee_values = array(my_data['gas_detector']['f_22_ENRC'])[my_mask]
    
    my_bins = arange(930,942,0.5)
    IvsE = -nan_to_num(binned_statistic_dd(photon_energy,apd_amplitude,bins=[my_bins],statistic=average).statistic)
    I0vsE = nan_to_num(binned_statistic_dd(photon_energy,mcp_amplitude,bins=[my_bins],statistic=average).statistic)
   
    I_max.append(max(IvsE))
    I0_max.append(max(I0vsE))
    truncation_range = 1
    subplot(121)
    #plot(my_bins[1:][truncation_range:-truncation_range],IvsE[truncation_range:-truncation_range])
    plot(my_bins[1:][truncation_range:-truncation_range],IvsE[truncation_range:-truncation_range])
    subplot(122)
    plot(my_bins[1:][truncation_range:-truncation_range],I0vsE[truncation_range:-truncation_range])
    #subplot(133)
    #plot(IvsE[truncation_range:-truncation_range],I0vsE[truncation_range:-truncation_range])

    #plot(-apd_amplitude,mcp_amplitude,'.',alpha = 0.1)
    #plot(IvsE[truncation_range:-truncation_range],I0vsE[truncation_range:-truncation_range],'r.')
# Out:
# /reg/g/psdm/sw/conda/inst/miniconda2-prod-rhel7/envs/ana-1.3.55/lib/python2.7/site-packages/ipykernel/__main__.py:10: RuntimeWarning: invalid value encountered in greater
# /reg/g/psdm/sw/conda/inst/miniconda2-prod-rhel7/envs/ana-1.3.55/lib/python2.7/site-packages/ipykernel/__main__.py:11: RuntimeWarning: invalid value encountered in less

# %%
photon_energy = nan_to_num(array(my_data['ebeam']['photon_energy']))
mcp_amplitude = nan_to_num(array(my_data['mcp_data']))
apd_amplitude = -nan_to_num(array(my_data['apd_data']))
fee_values = nan_to_num(array(my_data['gas_detector']['f_22_ENRC']))
plot(apd_amplitude,mcp_amplitude,'.',alpha=0.01,)
photon_e_mask = my_bins<938
photon_e_mask = photon_e_mask*(my_bins>934)
plot(IvsE[photon_e_mask],I0vsE[photon_e_mask],linewidth=2)
plot(I_max,I0_max,'r',marker='o',linewidth = 0,markersize=12)
# Out:
# /reg/g/psdm/sw/conda/inst/miniconda2-prod-rhel7/envs/ana-1.3.55/lib/python2.7/site-packages/ipykernel/__main__.py:9: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 23 but corresponding boolean dimension is 24

# %%
plot(-1*array(my_data['apd_data']),my_data['mcp_data'],'.')

# %%
plot(mcp_traces[0])
plot(mcp_traces[400])
plot(mcp_traces[800])
show()

plot(apd_traces[0])
plot(apd_traces[400])
plot(apd_traces[300])
show()

# %% [markdown]
# #### aligning waveforms

# %%
#ch1_waves = 0+apd_traces
#temp = ch1_waves[0]
#for i in ch1_waves:
    #shift_amount = 6352-argmax(convolve(ch1_waves[0],i))+100
#    shift_amount = 75-argmax(convolve(diff(ch1_waves[0]),diff(i)))+400
#    if(shift_amount<0): shift_amount = 1
#    temp = vstack([temp,append(zeros(shift_amount),i[:-shift_amount])])

#temp =temp[1:]

# %%
ch1_waves = mcp_traces
ch2_waves = apd_traces

# %%
plot(ch1_waves[0])
plot(ch1_waves[400])
plot(ch1_waves[800])
#xlim(115,130)
show()

# %% [markdown]
# #### fourier analysis

# %%
plot(sum(abs(fft(ch1_waves[:,500:],axis=1)),axis=0)[:350] )
show()
plot(ch2_waves[0,190:230])
show()

# %%
mcp_amplitude = sum(abs(fft(ch1_waves[:,400:],axis=1))[:,20:50],axis=1)
apd_amplitude = sum(ch2_waves[:,190:230],axis=1)

# %%
plot(-apd_amplitude,mcp_amplitude,'o')
show()

# %%
hist(photon_energy,bins=arange(930,940,0.1))

# %%
my_bins = arange(930,940,0.1)
IvsE = -nan_to_num(binned_statistic_dd(photon_energy,apd_amplitude,bins=[my_bins],statistic=average).statistic)
I0vsE = nan_to_num(binned_statistic_dd(photon_energy,mcp_amplitude,bins=[my_bins],statistic=average).statistic)

# %%
my_bins = arange(930,940,0.1)
IvsE = -nan_to_num(binned_statistic_dd(photon_energy,apd_amplitude,bins=[my_bins],statistic=average).statistic)
I0vsE = nan_to_num(binned_statistic_dd(photon_energy,mcp_amplitude,bins=[my_bins],statistic=average).statistic)
truncation_range = 13
plot(my_bins[1:][truncation_range:-truncation_range],IvsE[truncation_range:-truncation_range])
plot(my_bins[1:][truncation_range:-truncation_range],I0vsE[truncation_range:-truncation_range])

# %%
my_bins = arange(930,940,0.1)
IvsE = -nan_to_num(binned_statistic_dd(photon_energy,apd_amplitude,bins=[my_bins],statistic=average).statistic)
I0vsE = nan_to_num(binned_statistic_dd(photon_energy,mcp_amplitude,bins=[my_bins],statistic=average).statistic)
truncation_range = 13
plot(my_bins[1:][truncation_range:-truncation_range],IvsE[truncation_range:-truncation_range])
plot(my_bins[1:][truncation_range:-truncation_range],I0vsE[truncation_range:-truncation_range])
plot(-apd_amplitude,mcp_amplitude,'.',alpha = 0.1)
plot(IvsE[truncation_range:-truncation_range],I0vsE[truncation_range:-truncation_range],'.')
